# %%
import pandas as pd
df=pd.read_csv("delivery_time.csv")
y=df[["Delivery Time"]]
x=df[['Sorting Time']]
co=df.corr()
print(co)
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x,y)
y_pred=LR.predict(x)
plt.scatter(x,y)
plt.scatter(x,y_pred,color='red')
plt.plot(x,y_pred, color='black')
plt.xlabel('Sorting Time')
plt.ylabel('Delivery Time')
plt.show()
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,y_pred)
import numpy as np
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000
# Mean Squared Error is:  7.793311548584063
# Root Mean Square Error is:  2.7916503270617654

# %%
x1=x*x
#plt.scatter(x1,y)

LR.fit(x1,y)
y_pred=LR.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,y_pred)
import numpy as np
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  9.068393138438141
# Root Mean Square Error is:  3.011377282646288

# %%
x1=np.sqrt(x)
#plt.scatter(x1,y)
LR.fit(x1,y)
y_pred=LR.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  7.461328308595395
# Root Mean Square Error is:  2.7315432100912105

# %%
x1=np.log(x)
#plt.scatter(x1,y)
LR.fit(x1,y)
y_pred=LR.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  7.470226320948425
# Root Mean Square Error is:  2.733171476682066

# %%
x1=pow(x,3)
#plt.scatter(x1,y)
LR.fit(x1,y)
y_pred=LR.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  10.580708992991031
# Root Mean Square Error is:  3.2528001772305397

# %%
x1=pow(x,(1/3))
#plt.scatter(x1,y)
LR.fit(x1,y)
y_pred=LR.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  7.421788796948225
# Root Mean Square Error is:  2.7242960185978733

# %%
x1=(1/x)
#plt.scatter(x1,y)
LR.fit(x1,y)
y_pred=LR.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  8.748373874623386
# Root Mean Square Error is:  2.957765013422024

# %%
x1=1/(np.sqrt(x))
#plt.scatter(x1,y)
LR.fit(x1,y)
y_pred=LR.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  7.895150319526167
# Root Mean Square Error is:  2.8098310126280133

# %% [markdown]
# By comparing all the above transformations we conclude that cube root of x variable is getting low rmse

# %% [markdown]
# # Q2) Salary_hike -> Build a prediction model for Salary_hike

# %%
import pandas as pd
df=pd.read_csv("Salary_data.csv")
y=df[['Salary']]
x=df[['YearsExperience']]
import matplotlib.pyplot as plt
plt.scatter(x,y)
print(df.corr())
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
y_pred=lr.predict(x)
plt.scatter(x,y,color='blue')
plt.scatter(x,y_pred,color='red')
plt.plot(x,y_pred, color='black')
plt.show()
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,y_pred)
import numpy as np
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000
# Mean Squared Error is:  31270951.722280968
# Root Mean Square Error is:  5592.043608760662

# %%
x1=np.log(x)
#plt.scatter(x1,y)
lr.fit(x1,y)
y_pred=lr.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  106149618.72183877
# Root Mean Square Error is:  10302.893706228302

# %%
x1=pow(x,2)
#plt.scatter(x1,y)
lr.fit(x1,y)
y_pred=lr.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  61520040.46050559
# Root Mean Square Error is:  7843.471199698867

# %%
x1=pow(x,3)
#plt.scatter(x1,y)
LR.fit(x1,y)
y_pred=LR.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  120426604.55754934
# Root Mean Square Error is:  10973.905620040176

# %%
x1=pow(x,(1/2))
#plt.scatter(x1,y)
LR.fit(x1,y)
y_pred=LR.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  50127755.61652502
# Root Mean Square Error is:  7080.095734983039

# %%
x1=pow(x,(1/3))
#plt.scatter(x1,y)
LR.fit(x1,y)
y_pred=LR.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  64433306.67973567
# Root Mean Square Error is:  8027.035983458381

# %%
x1=(1/x)
#plt.scatter(x1,y)
LR.fit(x1,y)
y_pred=LR.predict(x1)
plt.scatter(x1,y,color='blue')
plt.scatter(x1,y_pred,color='red')
plt.plot(x1,y_pred, color='black')
plt.show()
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared Error is: ", mse)
print("Root Mean Square Error is: ", rmse)
# Out:
# Mean Squared Error is:  298885351.1155213
# Root Mean Square Error is:  17288.30098984632

# %% [markdown]
# By comparing all the above we conclude that without transforamtion only we get low RMSE
